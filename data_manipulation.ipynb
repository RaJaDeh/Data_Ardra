# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn  as sns

# %%
df = pd.read_csv('market_data.csv')

# %%
df
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
df.isna().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
for col in df.columns:
    if df[col].dtype == 'object':
        print(df[col].unique())
        print(df[col].value_counts())
        print('')
# Out:
# ['FDA15' 'DRC01' 'FDN15' ... 'NCF55' 'NCW30' 'NCW05']
# Item_Identifier
# FDW13    10
# FDG33    10
# FDX31     9
# FDT07     9
# NCY18     9
#          ..
# FDO33     1
# FDK57     1
# FDT35     1
# FDN52     1
# FDE52     1
# Name: count, Length: 1559, dtype: int64
#
# ['Low Fat' 'Regular' 'low fat' 'LF' 'reg']
# Item_Fat_Content
# Low Fat    5089
# Regular    2889
# LF          316
# reg         117
# low fat     112
# Name: count, dtype: int64
#
# ['Dairy' 'Soft Drinks' 'Meat' 'Fruits and Vegetables' 'Household'
#  'Baking Goods' 'Snack Foods' 'Frozen Foods' 'Breakfast'
#  'Health and Hygiene' 'Hard Drinks' 'Canned' 'Breads' 'Starchy Foods'
#  'Others' 'Seafood']
# Item_Type
# Fruits and Vegetables    1232
# Snack Foods              1200
# Household                 910
# Frozen Foods              856
# Dairy                     682
# Canned                    649
# Baking Goods              648
# Health and Hygiene        520
# Soft Drinks               445
# ...

# %% [markdown]
# ### Standardize Words

# %%
fat_map = {

    'lf' : 'Low Fat',
    'reg' : 'Regular',
    'low fat' : 'Low Fat',
    'regular' : 'Regular'

}

# %%
df['Item_Fat_Content'] = df['Item_Fat_Content'].map(lambda x: fat_map.get(x.lower(), x))

# %%
df['Item_Fat_Content'].value_counts()
# Out:
# Item_Fat_Content
# Low Fat    5517
# Regular    3006
# Name: count, dtype: int64

# %% [markdown]
# ### Item Wieght Null Handling

# %%
df
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
df.Item_Weight.describe()
# Out:
# count    7060.000000
# mean       12.857645
# std         4.643456
# min         4.555000
# 25%         8.773750
# 50%        12.600000
# 75%        16.850000
# max        21.350000
# Name: Item_Weight, dtype: float64

# %%
df.sort_values('Item_Identifier')
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 8043           DRA12        11.60          Low Fat         0.068535
# 118            DRA12        11.60          Low Fat         0.041178
# 1693           DRA12        11.60          Low Fat         0.000000
# 1197           DRA12        11.60          Low Fat         0.000000
# 1245           DRA12        11.60          Low Fat         0.040912
# ...              ...          ...              ...              ...
# 7926           NCZ54        14.65          Low Fat         0.083489
# 214            NCZ54        14.65          Low Fat         0.000000
# 1896           NCZ54          NaN          Low Fat         0.082956
# 7166           NCZ54          NaN          Low Fat         0.145952
# 7738           NCZ54        14.65          Low Fat         0.083699
#
#         Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 8043  Soft Drinks  143.0154            OUT010                       1998
# ...

# %%
# Buat mapping dari Item_Identifier ke satu nilai Item_Weight yang diketahui (bukan NaN)
weight_map = df.loc[df['Item_Weight'].notna()].drop_duplicates('Item_Identifier').set_index('Item_Identifier')['Item_Weight']

# Isi NaN berdasarkan mapping ini
df['Item_Weight'] = df['Item_Weight'].fillna(df['Item_Identifier'].map(weight_map))

# %%
df.dropna(inplace=True)

# %%
pd.crosstab(df['Outlet_Size'], df['Outlet_Type'])
# Out:
# Outlet_Type  Grocery Store  Supermarket Type1  Supermarket Type2  \
# Outlet_Size
# High                     0                932                  0
# Medium                   0                930                928
# Small                  527               1860                  0
#
# Outlet_Type  Supermarket Type3
# Outlet_Size
# High                         0
# Medium                     932
# Small                        0

# %%
df_test = df.copy()

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                8523 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                8523 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
pd.crosstab(df_test['Outlet_Size'], df_test['Outlet_Type'])
# Out:
# Outlet_Type  Grocery Store  Supermarket Type1  Supermarket Type2  \
# Outlet_Size
# High                     0                932                  0
# Medium                   0                930                928
# Small                  528               1860                  0
# Unknown                555               1855                  0
#
# Outlet_Type  Supermarket Type3
# Outlet_Size
# High                         0
# Medium                     935
# Small                        0
# Unknown                      0

# %%
pd.crosstab(df_test['Outlet_Size'], df_test['Outlet_Identifier'])
# Out:
# Outlet_Identifier  OUT010  OUT013  OUT017  OUT018  OUT019  OUT027  OUT035  \
# Outlet_Size
# High                    0     932       0       0       0       0       0
# Medium                  0       0       0     928       0     935       0
# Small                   0       0       0       0     528       0     930
# Unknown               555       0     926       0       0       0       0
#
# Outlet_Identifier  OUT045  OUT046  OUT049
# Outlet_Size
# High                    0       0       0
# Medium                  0       0     930
# Small                   0     930       0
# Unknown               929       0       0

# %%
pd.crosstab(df_test['Outlet_Type'], df_test['Outlet_Identifier'])
# Out:
# Outlet_Identifier  OUT010  OUT013  OUT017  OUT018  OUT019  OUT027  OUT035  \
# Outlet_Type
# Grocery Store         555       0       0       0     528       0       0
# Supermarket Type1       0     932     926       0       0       0     930
# Supermarket Type2       0       0       0     928       0       0       0
# Supermarket Type3       0       0       0       0       0     935       0
#
# Outlet_Identifier  OUT045  OUT046  OUT049
# Outlet_Type
# Grocery Store           0       0       0
# Supermarket Type1     929     930     930
# Supermarket Type2       0       0       0
# Supermarket Type3       0       0       0

# %%
df[(df['Outlet_Location_Type'] == 'Tier 2') & (df['Outlet_Size'].isna())]
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 8              FDH17        16.20          Regular         0.016687
# 9              FDU28        19.20          Regular         0.094450
# 25             NCD06        13.00          Low Fat         0.099887
# 33             FDO23        17.85          Low Fat         0.000000
# 46             NCP05        19.60          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8501           FDW21         5.34          Regular         0.005998
# 8502           NCH43         8.42          Low Fat         0.070712
# 8508           FDW31        11.35          Regular         0.043246
# 8514           FDA01        15.00          Regular         0.054489
# 8519           FDS36         8.38          Regular         0.046982
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 8              Frozen Foods   96.9726            OUT045
# ...

# %%
# Mapping Outlet_Identifier → Outlet_Size
Mode_map = {
    'OUT045': 'High',
    'OUT017': 'Medium',
    'OUT010': 'Small',
}

# Isi NaN di Outlet_Size berdasarkan Outlet_Identifier
df['Outlet_Size'] = df['Outlet_Size'].fillna(df['Outlet_Identifier'].map(Mode_map))

# %%
df.isnull().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  4
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %%
df
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...
